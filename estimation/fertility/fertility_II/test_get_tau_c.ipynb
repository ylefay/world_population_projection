# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from estimation.fertility.fertility_II.PMMH_fertility_II import get_tau_c

# %%
LIST_OF_STAGE_II_COUNTRIES = pd.read_csv("../../../data/UN/fertility/countries_in_stage_II.csv")
SAVING_FILE_PREFIX = "../../../output/estimation/fertility_II/PMMH_fertility_II_"  # Add the country name to this prefix
TFR_OF_STAGE_II_COUNTRIES = pd.read_csv("../../../data/UN/fertility/TFR_per_country_stage_II.csv")



for country in LIST_OF_STAGE_II_COUNTRIES['Region']:
    DATA = TFR_OF_STAGE_II_COUNTRIES[TFR_OF_STAGE_II_COUNTRIES['Region'] == country]['TFR']
    DATA = np.array(DATA)
    print(country, get_tau_c(DATA))
    plt.plot(DATA)
    plt.show()
# Out:
# WORLD 0
# Sub-Saharan_Africa 0
# Northern_Africa_and_Western_Asia 0
# Central_and_Southern_Asia 0
# Oceania_(excluding_Australia_and_New_Zealand) 0
# Less_developed_regions 18
# Least_developed_countries 0
# Less_developed_regions,_excluding_least_developed_countries 4
# Less_developed_regions,_excluding_China 1
# Land-locked_Developing_Countries_(LLDC) 1
# Small_Island_Developing_States_(SIDS) 6
# Middle-income_countries 18
# Lower-middle-income_countries 0
# Low-income_countries 1
# No_income_group_available 7
# AFRICA 0
# Eastern_Africa 4
# Burundi 2
# Comoros 8
# Djibouti 9
# Eritrea 7
# Ethiopia 18
# Kenya 7
# Madagascar 0
# Malawi 13
# Mayotte 1
# Mozambique 9
# Réunion 4
# Rwanda 0
# Seychelles 17
# Somalia 8
# South_Sudan 46
# Uganda 3
# United_Republic_of_Tanzania 1
# Zambia 7
# Zimbabwe 23
# Middle_Africa 15
# Angola 14
# Cameroon 20
# Central_African_Republic 0
# Chad 23
# Congo 0
# Democratic_Republic_of_the_Congo 59
# Equatorial_Guinea 9
# Gabon 27
# Sao_Tome_and_Principe 6
# Northern_Africa 0
# Algeria 2
# Egypt 0
# Libya 13
# Morocco 3
# Sudan 8
# Tunisia 2
# Western_Sahara 16
# Southern_Africa 0
# Botswana 0
# Eswatini 5
# Lesotho 0
# Namibia 8
# South_Africa 0
# Western_Africa 28
# Benin 14
# Burkina_Faso 23
# Côte_d'Ivoire 0
# Gambia 48
# Ghana 0
# Guinea 14
# Guinea-Bissau 35
# Liberia 11
# Mali 6
# Mauritania 27
# Niger 16
# Nigeria 28
# Senegal 0
# Sierra_Leone 7
# Togo 25
# Central_Asia 9
# Kazakhstan 0
# Kyrgyzstan 0
# Tajikistan 10
# Turkmenistan 9
# Uzbekistan 10
# Mongolia 12
# Southern_Asia 0
# Afghanistan 0
# India 0
# Nepal 26
# Pakistan 0
# South-Eastern_Asia 1
# Cambodia 34
# Indonesia 9
# Lao_People's_Democratic_Republic 1
# Myanmar 0
# Philippines 12
# Timor-Leste 13
# Western_Asia 6
# Georgia 0
# Iraq 2
# Israel 0
# Jordan 19
# Kuwait 0
# Lebanon 1
# Oman 31
# Saudi_Arabia 1
# State_of_Palestine 12
# Syrian_Arab_Republic 12
# Yemen 35
# Faroe_Islands 0
# Monaco 0
# Caribbean 0
# Dominican_Republic 0
# Grenada 5
# Guadeloupe 0
# Haiti 4
# Saint_Martin_(French_part) 1
# United_States_Virgin_Islands 8
# Belize 23
# Guatemala 0
# Honduras 0
# Nicaragua 3
# Panama 0
# Bolivia_(Plurinational_State_of) 1
# Ecuador 0
# French_Guiana 0
# Guyana 2
# Paraguay 0
# Peru 0
# Suriname 3
# Venezuela_(Bolivarian_Republic_of) 7
# OCEANIA 0
# Melanesia 0
# Fiji 1
# New_Caledonia 0
# Papua_New_Guinea 1
# Solomon_Islands 12
# Vanuatu 14
# Micronesia 0
# Guam 11
# Kiribati 0
# Marshall_Islands 5
# Micronesia_(Fed._States_of) 0
# Nauru 0
# Northern_Mariana_Islands 18
# Palau 3
# Polynesia 0
# American_Samoa 6
# Cook_Islands 0
# Niue 2
# Samoa 0
# Tokelau 1
# Tonga 0
# Tuvalu 0

# %%
for
